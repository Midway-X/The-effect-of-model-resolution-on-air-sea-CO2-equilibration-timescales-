# %%
from google.colab import drive
drive.mount('/gdrive')
# %cd /gdrive
# Out:
# Drive already mounted at /gdrive; to attempt to forcibly remount, call drive.mount("/gdrive", force_remount=True).
# /gdrive

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
df = pd.read_hdf('MyDrive/MyPapers/limitpaper/data/he_tyka_uptake_curves.h5')
df
# Out:
#          time       eta     key
# key
# brazil   0.00  0.066766  brazil
# brazil   0.25  0.276812  brazil
# brazil   0.50  0.445029  brazil
# brazil   0.75  0.536239  brazil
# brazil   1.00  0.602513  brazil
# ...       ...       ...     ...
# oman    17.75  0.781041    oman
# oman    18.00  0.781203    oman
# oman    18.25  0.781383    oman
# oman    18.50  0.781711    oman
# oman    18.75  0.781486    oman
#
# [1283 rows x 3 columns]

# %%
#df = pd.read_hdf('he_tyka_uptake_curves.h5')
plt.plot(df.loc['brazil']['time'],df.loc['brazil']['eta'], label='brazil')
plt.plot(df.loc['island']['time'],df.loc['island']['eta'], label='island')
plt.plot(df.loc['hawaii']['time'],df.loc['hawaii']['eta'], label='hawaii')
plt.legend(loc="lower right")
